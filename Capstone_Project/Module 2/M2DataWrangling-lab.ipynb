# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="400" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pyodide.http import pyfetch
#       3 async def download(url, filename):
#       4     response = await pyfetch(url)
#
# ModuleNotFoundError: No module named 'pyodide'

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv"

# %% [markdown]
# To obtain the dataset, utilize the download() function as defined above:

# %%
await download(file_path, "m1_survey_data.csv")
file_name="m1_survey_data.csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 await download(file_path, "m1_survey_data.csv")
#       2 file_name="m1_survey_data.csv"
#
# NameError: name 'download' is not defined

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface.While working on the downloaded version of this notebook on their local machines(Jupyter Anaconda), the learners can simply **skip the steps above,** and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
df_duplicate_check = df.duplicated()
#  now filter by duplicate
df_duplicate_check
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11547    False
# 11548    False
# 11549    False
# 11550    False
# 11551    False
# Length: 11552, dtype: bool

# %%
df_duplicate_checks_true = df_duplicate_check[lambda x : x == True]
df_duplicate_checks_true
# Out:
# 1168    True
# 1169    True
# 1170    True
# 1171    True
# 1172    True
#         ...
# 2297    True
# 2298    True
# 2299    True
# 2300    True
# 2301    True
# Length: 154, dtype: bool

# %%
print("No. of duplicate values: ", len(df_duplicate_checks_true))
# Out:
# No. of duplicate values:  154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df_no_duplicates = df.drop_duplicates()
df_no_duplicates.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
len(df['Respondent'].duplicated()[lambda x : x == True])
# Out:
# 154

# %%
# your code goes here
df_duplicate_check = df_no_duplicates.duplicated()[lambda x : x == True]
len(df_duplicate_check)
# Out:
# 0

# %%
# compare the size of the data frame before and after removing duplicates
print("No. of entries (before): ", df.shape[0])
print("No. of entries (after): ", df_no_duplicates.shape[0])
# Out:
# No. of entries (before):  11552
# No. of entries (after):  11398

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
# collec all entries with missing data (i.e  null data)
df_missing_values = df_no_duplicates.isnull()
# now go through all of the columns to check for missing values
for column in df_missing_values.columns.values.tolist():
    print (df_missing_values[column].value_counts())
    print("")
# Out:
# Respondent
# False    11398
# Name: count, dtype: int64
#
# MainBranch
# False    11398
# Name: count, dtype: int64
#
# Hobbyist
# False    11398
# Name: count, dtype: int64
#
# OpenSourcer
# False    11398
# Name: count, dtype: int64
#
# OpenSource
# False    11317
# True        81
# Name: count, dtype: int64
#
# Employment
# False    11398
# Name: count, dtype: int64
#
# Country
# False    11398
# Name: count, dtype: int64
#
# Student
# False    11347
# True        51
# Name: count, dtype: int64
#
# EdLevel
# False    11286
# True       112
# Name: count, dtype: int64
#
# UndergradMajor
# False    10661
# True       737
# Name: count, dtype: int64
#
# EduOther
# False    11234
# True       164
# Name: count, dtype: int64
#
# OrgSize
# False    11302
# True        96
# Name: count, dtype: int64
#
# DevType
# False    11333
# True        65
# Name: count, dtype: int64
#
# YearsCode
# False    11389
# True         9
# Name: count, dtype: int64
#
# Age1stCode
# False    11385
# ...

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
len(df_no_duplicates['WorkLoc'].isnull()[lambda x: x == True])
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df_no_duplicates['WorkLoc'].value_counts()
# Out:
# WorkLoc
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: count, dtype: int64

# %%
df_no_duplicates['CompFreq'].value_counts()
# Out:
# CompFreq
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: count, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
workloc_most_freq_val = df_no_duplicates['WorkLoc'].value_counts().idxmax()
workloc_most_freq_val
# Out:
# 'Office'

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
print(df_no_duplicates['Employment'].value_counts().idxmax())
print(df_no_duplicates['UndergradMajor'].value_counts().idxmin())
# Out:
# Employed full-time
# A health science (ex. nursing, pharmacy, radiology)

# %%
# your code goes here
df_no_duplicates['WorkLoc'].replace(np.nan, workloc_most_freq_val, inplace=True)
df_no_duplicates.head(20)
# Out:
# C:\Users\ridwa\AppData\Local\Temp\ipykernel_25044\3533299931.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_no_duplicates['WorkLoc'].replace(np.nan, workloc_most_freq_val, inplace=True)
# C:\Users\ridwa\AppData\Local\Temp\ipykernel_25044\3533299931.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
len(df_no_duplicates['WorkLoc'].isnull()[lambda x: x == True])
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df_no_duplicates['CompFreq']
# Out:
# 0         Yearly
# 1         Yearly
# 2         Yearly
# 3        Monthly
# 4         Yearly
#           ...
# 11547     Yearly
# 11548     Yearly
# 11549     Yearly
# 11550     Yearly
# 11551        NaN
# Name: CompFreq, Length: 11398, dtype: object

# %%
print("Compensation categories")
df_no_duplicates['CompFreq'].unique()
# Out:
# Compensation categories
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %%
df_no_duplicates['CompTotal']
# Out:
# 0         61000.0
# 1        138000.0
# 2         90000.0
# 3         29000.0
# 4         90000.0
#            ...
# 11547    130000.0
# 11548     74400.0
# 11549    105000.0
# 11550     80000.0
# 11551         NaN
# Name: CompTotal, Length: 11398, dtype: float64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# but first, replace missing values
comp_type_freq_val = df_no_duplicates['CompFreq'].value_counts().idxmax()
df_no_duplicates['CompFreq'].replace(np.nan, comp_type_freq_val, inplace=True)
df_no_duplicates
# Out:
# C:\Users\ridwa\AppData\Local\Temp\ipykernel_25044\3130752018.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_duplicates['CompFreq'].replace(np.nan, comp_type_freq_val, inplace=True)
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# ...

# %%
# but before replacing the missing values, let's  normalize the data first
def comp_norm_conditions(df):
    if (df['CompFreq'] == 'Yearly' and df['CompTotal'] is not np.nan):
        return df['CompTotal'] 
    elif (df['CompFreq'] == 'Monthly'):
        return df['CompTotal'] * 12
    elif (df['CompFreq'] == 'Weekly'):
        return df['CompTotal'] * 52
        
df_no_duplicates["NormalizedAnnualCompensation"] = df_no_duplicates.apply(comp_norm_conditions, axis = 1)
df_no_duplicates.head()
# Out:
# C:\Users\ridwa\AppData\Local\Temp\ipykernel_25044\486315979.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_duplicates["NormalizedAnnualCompensation"] = df_no_duplicates.apply(comp_norm_conditions, axis = 1)
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# ...

# %%
df_no_duplicates[["CompTotal","CompFreq","NormalizedAnnualCompensation"]].head()
# Out:
#    CompTotal CompFreq  NormalizedAnnualCompensation
# 0    61000.0   Yearly                       61000.0
# 1   138000.0   Yearly                      138000.0
# 2    90000.0   Yearly                       90000.0
# 3    29000.0  Monthly                      348000.0
# 4    90000.0   Yearly                       90000.0

# %%
# now replace missing values for compensation total
comp_median_val = df_no_duplicates['NormalizedAnnualCompensation'].median()
df_no_duplicates['NormalizedAnnualCompensation'].replace(np.nan, comp_median_val, inplace=True)
df_no_duplicates['CompTotal'].replace(np.nan, comp_median_val, inplace=True)
print("Done")
# Out:
# Done
# C:\Users\ridwa\AppData\Local\Temp\ipykernel_25044\4101668024.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_no_duplicates['NormalizedAnnualCompensation'].replace(np.nan, comp_median_val, inplace=True)
# C:\Users\ridwa\AppData\Local\Temp\ipykernel_25044\4101668024.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
comp_median_val = df_no_duplicates['NormalizedAnnualCompensation'].median()
comp_median_val
# Out:
# np.float64(100000.0)

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
#  ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>
